# %%
# !pip install mujoco
# !pip install mujoco_mjx
# !pip install brax
# Out:
# Requirement already satisfied: mujoco in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: absl-py in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco) (2.0.0)
# Requirement already satisfied: etils[epath] in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco) (1.6.0)
# Requirement already satisfied: glfw in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco) (2.6.3)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco) (1.26.2)
# Requirement already satisfied: pyopengl in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco) (3.1.7)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco) (2023.12.2)
# Requirement already satisfied: importlib_resources in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco) (6.1.1)
# Requirement already satisfied: typing_extensions in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco) (4.9.0)
# Requirement already satisfied: zipp in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco) (3.17.0)
# Requirement already satisfied: mujoco_mjx in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: absl-py in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (2.0.0)
# Requirement already satisfied: etils[epath] in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (1.6.0)
# Requirement already satisfied: jax in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (0.4.21)
# Requirement already satisfied: jaxlib in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (0.4.21)
# Requirement already satisfied: mujoco>=3.0.1.dev0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (3.0.1)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (1.11.4)
# Requirement already satisfied: trimesh in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco_mjx) (4.0.5)
# Requirement already satisfied: glfw in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco>=3.0.1.dev0->mujoco_mjx) (2.6.3)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco>=3.0.1.dev0->mujoco_mjx) (1.26.2)
# Requirement already satisfied: pyopengl in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco>=3.0.1.dev0->mujoco_mjx) (3.1.7)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco_mjx) (2023.12.2)
# Requirement already satisfied: importlib_resources in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco_mjx) (6.1.1)
# Requirement already satisfied: typing_extensions in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco_mjx) (4.9.0)
# Requirement already satisfied: zipp in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco_mjx) (3.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from jax->mujoco_mjx) (0.3.1)
# Requirement already satisfied: opt-einsum in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from jax->mujoco_mjx) (3.3.0)
# Collecting brax
#   Downloading brax-0.9.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: absl-py in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (2.0.0)
# Collecting dm-env (from brax)
#   Downloading dm_env-1.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: etils in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (1.6.0)
# Collecting flask (from brax)
#   Downloading flask-3.0.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting flask-cors (from brax)
#   Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting flax (from brax)
#   Downloading flax-0.7.5-py3-none-any.whl.metadata (10 kB)
# Collecting grpcio (from brax)
#   Using cached grpcio-1.60.0-cp310-cp310-macosx_12_0_universal2.whl.metadata (4.0 kB)
# Collecting gym (from brax)
#   Using cached gym-0.26.2-py3-none-any.whl
# Requirement already satisfied: jax>=0.4.6 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (0.4.21)
# Requirement already satisfied: jaxlib>=0.4.6 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (0.4.21)
# Collecting jaxopt (from brax)
#   Downloading jaxopt-0.8.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (3.1.2)
# Collecting ml-collections (from brax)
#   Downloading ml_collections-0.1.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mujoco in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (3.0.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (1.26.2)
# Collecting optax (from brax)
#   Downloading optax-0.1.7-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (10.1.0)
# Collecting pytinyrenderer (from brax)
#   Downloading pytinyrenderer-0.0.14.tar.gz (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.7 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (1.11.4)
# Collecting tensorboardX (from brax)
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: trimesh in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (4.0.5)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from brax) (4.9.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from jax>=0.4.6->brax) (0.3.1)
# Requirement already satisfied: opt-einsum in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from jax>=0.4.6->brax) (3.3.0)
# Collecting dm-tree (from dm-env->brax)
#   Downloading dm_tree-0.1.8-cp310-cp310-macosx_11_0_arm64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 4.3 MB/s eta 0:00:00
# Collecting Werkzeug>=3.0.0 (from flask->brax)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting itsdangerous>=2.1.2 (from flask->brax)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.1.3 (from flask->brax)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting blinker>=1.6.2 (from flask->brax)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from jinja2->brax) (2.1.3)
# Collecting msgpack (from flax->brax)
#   Downloading msgpack-1.0.7-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting orbax-checkpoint (from flax->brax)
#   Downloading orbax_checkpoint-0.4.7-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorstore (from flax->brax)
#   Downloading tensorstore-0.1.51-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting rich>=11.1 (from flax->brax)
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting PyYAML>=5.4.1 (from flax->brax)
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from gym->brax) (3.0.0)
# Collecting gym-notices>=0.0.4 (from gym->brax)
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from ml-collections->brax) (1.16.0)
# Collecting contextlib2 (from ml-collections->brax)
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: glfw in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco->brax) (2.6.3)
# Requirement already satisfied: pyopengl in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from mujoco->brax) (3.1.7)
# Collecting chex>=0.1.5 (from optax->brax)
#   Downloading chex-0.1.85-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from tensorboardX->brax) (23.2)
# Collecting protobuf>=3.20 (from tensorboardX->brax)
#   Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting toolz>=0.9.0 (from chex>=0.1.5->optax->brax)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 2.1 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax->brax)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from rich>=11.1->flax->brax) (2.17.2)
# Requirement already satisfied: fsspec in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco->brax) (2023.12.2)
# Requirement already satisfied: importlib_resources in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco->brax) (6.1.1)
# Requirement already satisfied: zipp in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from etils[epath]->mujoco->brax) (3.17.0)
# Requirement already satisfied: nest_asyncio in /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages (from orbax-checkpoint->flax->brax) (1.5.8)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax->brax)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading brax-0.9.3-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 34.9 MB/s eta 0:00:0000:0100:01
# Downloading flask-3.0.0-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 3.8 MB/s eta 0:00:00
# Downloading Flask_Cors-4.0.0-py2.py3-none-any.whl (14 kB)
# Downloading flax-0.7.5-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.4/244.4 kB 8.7 MB/s eta 0:00:00
# Using cached grpcio-1.60.0-cp310-cp310-macosx_12_0_universal2.whl (9.6 MB)
# Downloading jaxopt-0.8.2-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 kB 7.2 MB/s eta 0:00:00
# Downloading optax-0.1.7-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 6.6 MB/s eta 0:00:00
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading chex-0.1.85-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 4.1 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Downloading msgpack-1.0.7-cp310-cp310-macosx_11_0_arm64.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 9.2 MB/s eta 0:00:00
# Downloading orbax_checkpoint-0.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 5.3 MB/s eta 0:00:00
# Downloading tensorstore-0.1.51-cp310-cp310-macosx_11_0_arm64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 35.7 MB/s eta 0:00:0000:0100:01
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Building wheels for collected packages: ml-collections, pytinyrenderer
#   Building wheel for ml-collections (setup.py) ... done
#   Created wheel for ml-collections: filename=ml_collections-0.1.1-py3-none-any.whl size=94505 sha256=c03376595950431c303c2ae1a773d4bdfbd7b0386656ddd6154249265cb36f8e
#   Stored in directory: /Users/alexy/Library/Caches/pip/wheels/7b/89/c9/a9b87790789e94aadcfc393c283e3ecd5ab916aed0a31be8fe
#   Building wheel for pytinyrenderer (setup.py) ... done
#   Created wheel for pytinyrenderer: filename=pytinyrenderer-0.0.14-cp310-cp310-macosx_11_0_arm64.whl size=137024 sha256=b5cd4cf9df762c5028f275bfc60358a200999ba6c4efcf8e85a1174eacb7fa9c
#   Stored in directory: /Users/alexy/Library/Caches/pip/wheels/a2/66/ad/cf5f5ec645887d152627fd2552acb3f97d0fdd7a9fc71ba221
# Successfully built ml-collections pytinyrenderer
# Installing collected packages: pytinyrenderer, gym-notices, dm-tree, Werkzeug, toolz, PyYAML, protobuf, msgpack, mdurl, itsdangerous, gym, grpcio, dm-env, contextlib2, click, blinker, tensorstore, tensorboardX, ml-collections, markdown-it-py, flask, rich, orbax-checkpoint, jaxopt, flask-cors, chex, optax, flax, brax
# Successfully installed PyYAML-6.0.1 Werkzeug-3.0.1 blinker-1.7.0 brax-0.9.3 chex-0.1.85 click-8.1.7 contextlib2-21.6.0 dm-env-1.6 dm-tree-0.1.8 flask-3.0.0 flask-cors-4.0.0 flax-0.7.5 grpcio-1.60.0 gym-0.26.2 gym-notices-0.0.8 itsdangerous-2.1.2 jaxopt-0.8.2 markdown-it-py-3.0.0 mdurl-0.1.2 ml-collections-0.1.1 msgpack-1.0.7 optax-0.1.7 orbax-checkpoint-0.4.7 protobuf-4.25.1 pytinyrenderer-0.0.14 rich-13.7.0 tensorboardX-2.6.2.2 tensorstore-0.1.51 toolz-0.12.0

# %%
#@title Import packages for plotting and creating graphics
import time
import itertools
import numpy as np
from typing import Callable, NamedTuple, Optional, Union, List

# Graphics and plotting.
print('Installing mediapy:')
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
import mediapy as media
import matplotlib.pyplot as plt

# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)
# Out:
# Installing mediapy:

# %%
#@title Import MuJoCo, MJX, and Brax

from datetime import datetime
import functools
import jax
from jax import numpy as jp
import numpy as np
from typing import Any, Dict, Tuple, Union

from brax import envs
from brax import math
from brax.base import Base, Motion, Transform
from brax.envs.base import Env, State
from brax.training.agents.ppo import train as ppo
from brax.training.agents.ppo import networks as ppo_networks
from brax.io import model
from etils import epath
from flax import struct
from matplotlib import pyplot as plt
import mediapy as media
from ml_collections import config_dict
import mujoco
from mujoco import mjx

# %%
#@title State

@struct.dataclass
class State(Base):
  """Environment state for training and inference with brax.

  Args:
    pipeline_state: the physics state, mjx.Data
    obs: environment observations
    reward: environment reward
    done: boolean, True if the current episode has terminated
    metrics: metrics that get tracked per environment step
    info: environment variables defined and updated by the environment reset
      and step functions
  """

  pipeline_state: mjx.Data
  obs: jax.Array
  reward: jax.Array
  done: jax.Array
  metrics: Dict[str, jax.Array] = struct.field(default_factory=dict)
  info: Dict[str, Any] = struct.field(default_factory=dict)

# %%
#@title MjxEnv

class MjxEnv(Env):
  """API for driving an MJX system for training and inference in brax."""

  def __init__(
      self,
      mj_model: mujoco.MjModel,
      physics_steps_per_control_step: int = 1,
  ):
    """Initializes MjxEnv.

    Args:
      mj_model: mujoco.MjModel
      physics_steps_per_control_step: the number of times to step the physics
        pipeline for each environment step
    """
    self.model = mj_model
    self.data = mujoco.MjData(mj_model)
    self.sys = mjx.device_put(mj_model)
    self._physics_steps_per_control_step = physics_steps_per_control_step

  def pipeline_init(
      self, qpos: jax.Array, qvel: jax.Array
  ) -> mjx.Data:
    """Initializes the physics state."""
    data = mjx.device_put(self.data)
    data = data.replace(qpos=qpos, qvel=qvel, ctrl=jp.zeros(self.sys.nu))
    data = mjx.forward(self.sys, data)
    return data

  def pipeline_step(
      self, data: mjx.Data, ctrl: jax.Array
  ) -> mjx.Data:
    """Takes a physics step using the physics pipeline."""
    def f(data, _):
      data = data.replace(ctrl=ctrl)
      return (
          mjx.step(self.sys, data),
          None,
      )
    data, _ = jax.lax.scan(f, data, (), self._physics_steps_per_control_step)
    return data

  @property
  def dt(self) -> jax.Array:
    """The timestep used for each env step."""
    return self.sys.opt.timestep * self._physics_steps_per_control_step

  @property
  def observation_size(self) -> int:
    rng = jax.random.PRNGKey(0)
    reset_state = self.unwrapped.reset(rng)
    return reset_state.obs.shape[-1]

  @property
  def action_size(self) -> int:
    return self.sys.nu

  @property
  def backend(self) -> str:
    return 'mjx'

  def _pos_vel(
      self, data: mjx.Data
      ) -> Tuple[Transform, Motion]:
    """Returns 6d spatial transform and 6d velocity for all bodies."""
    x = Transform(pos=data.xpos[1:, :], rot=data.xquat[1:, :])
    cvel = Motion(vel=data.cvel[1:, 3:], ang=data.cvel[1:, :3])
    offset = data.xpos[1:, :] - data.subtree_com[
        self.model.body_rootid[np.arange(1, self.model.nbody)]]
    xd = Transform.create(pos=offset).vmap().do(cvel)
    return x, xd

# %%
#@title Humanoid Env

class Humanoid(MjxEnv):

  def __init__(
      self,
      forward_reward_weight=1.25,
      ctrl_cost_weight=0.1,
      healthy_reward=5.0,
      terminate_when_unhealthy=True,
      healthy_z_range=(1.0, 2.0),
      reset_noise_scale=1e-2,
      exclude_current_positions_from_observation=True,
      **kwargs,
  ):
    path = epath.Path(epath.resource_path('mujoco')) / (
        'mjx/benchmark/model/humanoid'
    )
    mj_model = mujoco.MjModel.from_xml_path(
        (path / 'humanoid.xml').as_posix())
    mj_model.opt.solver = mujoco.mjtSolver.mjSOL_CG
    mj_model.opt.iterations = 6
    mj_model.opt.ls_iterations = 6

    physics_steps_per_control_step = 5
    kwargs['physics_steps_per_control_step'] = kwargs.get(
        'physics_steps_per_control_step', physics_steps_per_control_step)

    super().__init__(mj_model=mj_model, **kwargs)

    self._forward_reward_weight = forward_reward_weight
    self._ctrl_cost_weight = ctrl_cost_weight
    self._healthy_reward = healthy_reward
    self._terminate_when_unhealthy = terminate_when_unhealthy
    self._healthy_z_range = healthy_z_range
    self._reset_noise_scale = reset_noise_scale
    self._exclude_current_positions_from_observation = (
        exclude_current_positions_from_observation
    )

  def reset(self, rng: jp.ndarray) -> State:
    """Resets the environment to an initial state."""
    rng, rng1, rng2 = jax.random.split(rng, 3)

    low, hi = -self._reset_noise_scale, self._reset_noise_scale
    qpos = self.sys.qpos0 + jax.random.uniform(
        rng1, (self.sys.nq,), minval=low, maxval=hi
    )
    qvel = jax.random.uniform(
        rng2, (self.sys.nv,), minval=low, maxval=hi
    )

    data = self.pipeline_init(qpos, qvel)

    obs = self._get_obs(data, jp.zeros(self.sys.nu))
    reward, done, zero = jp.zeros(3)
    metrics = {
        'forward_reward': zero,
        'reward_linvel': zero,
        'reward_quadctrl': zero,
        'reward_alive': zero,
        'x_position': zero,
        'y_position': zero,
        'distance_from_origin': zero,
        'x_velocity': zero,
        'y_velocity': zero,
    }
    return State(data, obs, reward, done, metrics)

  def step(self, state: State, action: jp.ndarray) -> State:
    """Runs one timestep of the environment's dynamics."""
    data0 = state.pipeline_state
    data = self.pipeline_step(data0, action)

    com_before = data0.subtree_com[1]
    com_after = data.subtree_com[1]
    velocity = (com_after - com_before) / self.dt
    forward_reward = self._forward_reward_weight * velocity[0]

    min_z, max_z = self._healthy_z_range
    is_healthy = jp.where(data.qpos[2] < min_z, x=0.0, y=1.0)
    is_healthy = jp.where(
        data.qpos[2] > max_z, x=0.0, y=is_healthy
    )
    if self._terminate_when_unhealthy:
      healthy_reward = self._healthy_reward
    else:
      healthy_reward = self._healthy_reward * is_healthy

    ctrl_cost = self._ctrl_cost_weight * jp.sum(jp.square(action))

    obs = self._get_obs(data, action)
    reward = forward_reward + healthy_reward - ctrl_cost
    done = 1.0 - is_healthy if self._terminate_when_unhealthy else 0.0
    state.metrics.update(
        forward_reward=forward_reward,
        reward_linvel=forward_reward,
        reward_quadctrl=-ctrl_cost,
        reward_alive=healthy_reward,
        x_position=com_after[0],
        y_position=com_after[1],
        distance_from_origin=jp.linalg.norm(com_after),
        x_velocity=velocity[0],
        y_velocity=velocity[1],
    )

    return state.replace(
        pipeline_state=data, obs=obs, reward=reward, done=done
    )

  def _get_obs(
      self, data: mjx.Data, action: jp.ndarray
  ) -> jp.ndarray:
    """Observes humanoid body position, velocities, and angles."""
    position = data.qpos
    if self._exclude_current_positions_from_observation:
      position = position[2:]

    # external_contact_forces are excluded
    return jp.concatenate([
        position,
        data.qvel,
        data.cinert[1:].ravel(),
        data.cvel[1:].ravel(),
        data.qfrc_actuator,
    ])


envs.register_environment('humanoid', Humanoid)

# %%
# instantiate the environment
env_name = 'humanoid'
env = envs.get_environment(env_name)

# define the jit reset/step functions
jit_reset = jax.jit(env.reset)
jit_step = jax.jit(env.step)

# instantiate the renderer
renderer = mujoco.Renderer(env.model)

# %%
#@title Define a render utility function

def get_image(state: State, camera: str) -> np.ndarray:
  """Renders the environment state."""
  d = mujoco.MjData(env.model)
  # write the mjx.Data into an mjData object
  mjx.device_get_into(d, state.pipeline_state)
  mujoco.mj_forward(env.model, d)
  # use the mjData object to update the renderer
  renderer.update_scene(d, camera=camera)
  return renderer.render()

# %%
# initialize the state
state = jit_reset(jax.random.PRNGKey(0))
rollout = [state]
images = [get_image(state, camera='side')]

# grab a trajectory
for i in range(10):
  ctrl = -0.1 * jp.ones(env.sys.nu)
  state = jit_step(state, ctrl)
  rollout.append(state)
  images.append(get_image(state, camera='side'))

# media.show_video(images, fps=1.0 / env.dt)
# Out:
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:81: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(data.qpos[2] < min_z, x=0.0, y=1.0)
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:82: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
train_fn = functools.partial(
    ppo.train, num_timesteps=30_000_000, num_evals=5, reward_scaling=0.1,
    episode_length=1000, normalize_observations=True, action_repeat=1,
    unroll_length=10, num_minibatches=32, num_updates_per_batch=8,
    discounting=0.97, learning_rate=3e-4, entropy_cost=1e-3, num_envs=2048,
    batch_size=1024, seed=0)


x_data = []
y_data = []
ydataerr = []
times = [datetime.now()]

max_y, min_y = 13000, 0
def progress(num_steps, metrics):
  times.append(datetime.now())
  x_data.append(num_steps)
  y_data.append(metrics['eval/episode_reward'])
  ydataerr.append(metrics['eval/episode_reward_std'])

  plt.xlim([0, train_fn.keywords['num_timesteps'] * 1.25])
  plt.ylim([min_y, max_y])

  plt.xlabel('# environment steps')
  plt.ylabel('reward per episode')
  plt.title(f'y={y_data[-1]:.3f}')

  plt.errorbar(
      x_data, y_data, yerr=ydataerr)
  # plt.show()

make_inference_fn, params, _= train_fn(environment=env, progress_fn=progress)

print(f'time to jit: {times[1] - times[0]}')
print(f'time to train: {times[-1] - times[1]}')
# Out:
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:81: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(data.qpos[2] < min_z, x=0.0, y=1.0)
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:82: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(
# /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3672: RuntimeWarning: divide by zero encountered in negative
#   if np.any(np.less(err, -err, out=res, where=(err == err))):
# /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3672: RuntimeWarning: divide by zero encountered in equal
#   if np.any(np.less(err, -err, out=res, where=(err == err))):
# /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3672: RuntimeWarning: divide by zero encountered in less
#   if np.any(np.less(err, -err, out=res, where=(err == err))):
# /opt/homebrew/Caskroom/miniforge/base/envs/humanoids/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3680: RuntimeWarning: divide by zero encountered in add
#   low, high = dep + np.vstack([-(1 - lolims), 1 - uplims]) * err
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:81: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(data.qpos[2] < min_z, x=0.0, y=1.0)
# /var/folders/ts/3v49jkvx06z91kc356z9c41r0000gn/T/ipykernel_65396/3657967982.py:82: DeprecationWarning: Passing condition, x, or y to jax.numpy.where via keyword arguments is deprecated.
#   is_healthy = jp.where(

# %%
#@title Save Model
model_path = '/tmp/mjx_brax_policy'
model.save_params(model_path, params)

# %%
#@title Load Model and Define Inference Function
params = model.load_params(model_path)

inference_fn = make_inference_fn(params)
jit_inference_fn = jax.jit(inference_fn)

# %%
eval_env = envs.get_environment(env_name)

jit_reset = jax.jit(eval_env.reset)
jit_step = jax.jit(eval_env.step)

# %%
# initialize the state
rng = jax.random.PRNGKey(0)
state = jit_reset(rng)
rollout = [state]
images = [get_image(state, camera='side')]

# grab a trajectory
n_steps = 500
render_every = 2

for i in range(n_steps):
  act_rng, rng = jax.random.split(rng)
  ctrl, _ = jit_inference_fn(state.obs, act_rng)
  state = jit_step(state, ctrl)
  rollout.append(state)
  if i % render_every == 0:
    images.append(get_image(state, camera='side'))

  if state.done:
    break

# media.show_video(images, fps=1.0 / eval_env.dt / render_every)

# %%
mj_model = eval_env.model
mj_data = mujoco.MjData(mj_model)

renderer = mujoco.Renderer(mj_model)
ctrl = jp.zeros(mj_model.nu)

images = []
for i in range(n_steps):
  act_rng, rng = jax.random.split(rng)

  obs = eval_env._get_obs(mjx.device_put(mj_data), ctrl)
  ctrl, _ = jit_inference_fn(obs, act_rng)

  mj_data.ctrl = ctrl
  for _ in range(eval_env._physics_steps_per_control_step):
    mujoco.mj_step(mj_model, mj_data)  # Physics step using MuJoCo mj_step.

  if i % render_every == 0:
    renderer.update_scene(mj_data, camera='side')
    images.append(renderer.render())

# media.show_video(images, fps=1.0 / eval_env.dt / render_every)/
